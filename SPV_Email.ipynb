# %%
import pandas as pd
import seaborn as sms

# %%
data_set=pd.read_csv("Email.csv")

# %%
data_set
# Out:
#                                  Unnamed: 0  \
# 0      04B738A5-71FD-11e8-A0F8-00505682069A
# 1      894FAAD2-6F3C-11e8-9252-0050568252F9
# 2      0918CDD9-5788-11e9-93F0-005056984FDD
# 3      0EC2729D-1618-11e8-B598-0050569D5A2F
# 4      CAAEDBE3-B411-11e8-ACF0-00505682069A
# ...                                     ...
# 9997   8980002F-7F6D-11e8-9DF8-0050568260A3
# 9998   BB720E30-7186-11e8-9A3E-0050569D7549
# 9999   358D43A1-B588-11e8-B9A6-0050569D3164
# 10000  FF93F9C4-9B8A-11e8-9A0E-0050569D5A2F
# 10001  FF93F9C4-9B8A-11e8-9A0E-0050569D5A2F
#
#                                      CampaignCodJ Medium_Type  Is_Email_Sent  \
# 0                         J-IF-SS UNITECH-APR-HYD       Email              1
# 1          J-HY-SS UNITECH-UNIDJNTIFIJD-FWC-19DJC       Email              1
# 2                      J-ST-SS UNITECH-SURJ-20MAR       Email              1
# 3            J-PO-SS UNITECH-UM-SALJNOTIDJNTIFIJD       Email              1
# ...

# %%
data_set.head()
# Out:
#                              Unnamed: 0  \
# 0  04B738A5-71FD-11e8-A0F8-00505682069A
# 1  894FAAD2-6F3C-11e8-9252-0050568252F9
# 2  0918CDD9-5788-11e9-93F0-005056984FDD
# 3  0EC2729D-1618-11e8-B598-0050569D5A2F
# 4  CAAEDBE3-B411-11e8-ACF0-00505682069A
#
#                              CampaignCodJ Medium_Type  Is_Email_Sent  \
# 0                 J-IF-SS UNITECH-APR-HYD       Email              1
# 1  J-HY-SS UNITECH-UNIDJNTIFIJD-FWC-19DJC       Email              1
# 2              J-ST-SS UNITECH-SURJ-20MAR       Email              1
# 3    J-PO-SS UNITECH-UM-SALJNOTIDJNTIFIJD       Email              1
# 4               J-WO-SS UNITECH-YD-DUKTIG       Email              1
#
#   Email_Sent_Status Email_SentDate  Email_Open_Count  Email_Click_Count  \
# 0          Rejected       5-Apr-20                 0                  0
# 1              sent      19-Dec-19                 0                  0
# 2          Rejected      20-Mar-20                 0                  0
# ...

# %%
data_set.tail(5)
# Out:
#                                  Unnamed: 0  \
# 9997   8980002F-7F6D-11e8-9DF8-0050568260A3
# 9998   BB720E30-7186-11e8-9A3E-0050569D7549
# 9999   358D43A1-B588-11e8-B9A6-0050569D3164
# 10000  FF93F9C4-9B8A-11e8-9A0E-0050569D5A2F
# 10001  FF93F9C4-9B8A-11e8-9A0E-0050569D5A2F
#
#                                      CampaignCodJ Medium_Type  Is_Email_Sent  \
# 9997                       J-DC-SS UNITECH-YD-02B       Email              1
# 9998   J-MO-SS UNITECH--NONPMA-INACTIVJ-HYD-21NOV       Email              1
# 9999                 J-WO-SS UNITECH-YD-HJMNJS-04       Email              1
# 10000                      J-MO-SS UNITECH-HYD-01       Email              1
# 10001                      J-MO-SS UNITECH-HYD-01       Email              1
#
#       Email_Sent_Status Email_SentDate  Email_Open_Count  Email_Click_Count  \
# 9997               Sent      17-Nov-18                 0                  0
# 9998               Sent      21-Nov-19                 0                  0
# ...

# %%
# series is a 1-D array

Email_name = pd.Series(["Faisal", "Mahedi", "Rakib", "Baby"])
Email_country = pd.Series(["Bangladesh", "India", "Pakistan", "Uganda"])

# %%
Email_name
# Out:
# 0    Faisal
# 1    Mahedi
# 2     Rakib
# 3      Baby
# dtype: object

# %%
Email_country
# Out:
# 0    Bangladesh
# 1         India
# 2      Pakistan
# 3        Uganda
# dtype: object

# %%
# A dataframe is a 2D structure with key value

Email_data = pd.DataFrame({"Name":Email_name, "Country":Email_country})
Email_data
# Out:
#      Name     Country
# 0  Faisal  Bangladesh
# 1  Mahedi       India
# 2   Rakib    Pakistan
# 3    Baby      Uganda

# %%
data_set.dtypes
# Out:
# Unnamed: 0            object
# CampaignCodJ          object
# Medium_Type           object
# Is_Email_Sent          int64
# Email_Sent_Status     object
# Email_SentDate        object
# Email_Open_Count       int64
# Email_Click_Count      int64
# Is_SMS_Sent          float64
# SMS_SentDate         float64
# dtype: object

# %%
data_set.columns
# Out:
# Index(['Unnamed: 0', 'CampaignCodJ', 'Medium_Type', 'Is_Email_Sent',
#        'Email_Sent_Status', 'Email_SentDate', 'Email_Open_Count',
#        'Email_Click_Count', 'Is_SMS_Sent', 'SMS_SentDate'],
#       dtype='object')

# %%
data_set.index
# Out:
# RangeIndex(start=0, stop=10002, step=1)

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10002 entries, 0 to 10001
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         10002 non-null  object
#  1   CampaignCodJ       10002 non-null  object
#  2   Medium_Type        10002 non-null  object
#  3   Is_Email_Sent      10002 non-null  int64
#  4   Email_Sent_Status  9832 non-null   object
#  5   Email_SentDate     10002 non-null  object
#  6   Email_Open_Count   10002 non-null  int64
#  7   Email_Click_Count  10002 non-null  int64
#  8   Is_SMS_Sent        0 non-null      float64
#  9   SMS_SentDate       0 non-null      float64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 781.5+ KB

# %%
data_set.mean()
# Out:
# Is_Email_Sent        1.000000
# Email_Open_Count     0.209258
# Email_Click_Count    0.024195
# Is_SMS_Sent               NaN
# SMS_SentDate              NaN
# dtype: float64

# %%
data_set.groupby(["Email_Sent_Status"]).mean()
# Out:
#                    Is_Email_Sent  Email_Open_Count  Email_Click_Count  \
# Email_Sent_Status
# Bounced                      1.0          0.000000           0.000000
# Deferred                     1.0          0.000000           0.000000
# Rejected                     1.0          0.000000           0.000000
# Sent                         1.0          0.221681           0.025228
# SoftBounced                  1.0          0.000000           0.000000
# bounced                      1.0          0.000000           0.000000
# rejected                     1.0          0.000000           0.000000
# sent                         1.0          0.265664           0.033417
# soft-bounced                 1.0          0.000000           0.000000
#
#                    Is_SMS_Sent  SMS_SentDate
# Email_Sent_Status
# Bounced                    NaN           NaN
# Deferred                   NaN           NaN
# Rejected                   NaN           NaN
# Sent                       NaN           NaN
# ...

# %%
data_set.groupby(["Email_SentDate"]).mean()
# Out:
#                 Is_Email_Sent  Email_Open_Count  Email_Click_Count  \
# Email_SentDate
# 1-Aug-19                  1.0          0.388060           0.000000
# 1-Feb-20                  1.0          0.048387           0.000000
# 1-Mar-19                  1.0          0.352941           0.147059
# 1-Mar-20                  1.0          0.182927           0.006098
# 1-May-19                  1.0          0.121495           0.056075
# ...                       ...               ...                ...
# 8-Mar-19                  1.0          0.303704           0.014815
# 8-May-19                  1.0          0.352941           0.000000
# 8-Nov-19                  1.0          0.290323           0.010753
# 9-Apr-19                  1.0          0.300000           0.000000
# 9-Jun-18                  1.0          0.400000           0.050000
#
#                 Is_SMS_Sent  SMS_SentDate
# Email_SentDate
# 1-Aug-19                NaN           NaN
# 1-Feb-20                NaN           NaN
# ...

# %%
data_set.groupby(["Medium_Type"]).mean()
# Out:
#              Is_Email_Sent  Email_Open_Count  Email_Click_Count  Is_SMS_Sent  \
# Medium_Type
# Email                  1.0          0.209258           0.024195          NaN
#
#              SMS_SentDate
# Medium_Type
# Email                 NaN

# %%
people_wage = pd.Series([80.8, 55, 120.3])
people_wage.mean()
# Out:
# 85.36666666666667

# %%
data_set["Is_Email_Sent"].sum()
# Out:
# 10002

# %%
# plotting Data 

data_set["Email_Open_Count"].plot()
# Out:
# <AxesSubplot:>

# %%
data_set["Email_Open_Count"].hist()
# Out:
# <AxesSubplot:>

# %%
data_set['Email_Sent_Status'] = data_set['Email_Sent_Status'].str.lower()
data_set
# Out:
#                                  Unnamed: 0  \
# 0      04B738A5-71FD-11e8-A0F8-00505682069A
# 1      894FAAD2-6F3C-11e8-9252-0050568252F9
# 2      0918CDD9-5788-11e9-93F0-005056984FDD
# 3      0EC2729D-1618-11e8-B598-0050569D5A2F
# 4      CAAEDBE3-B411-11e8-ACF0-00505682069A
# ...                                     ...
# 9997   8980002F-7F6D-11e8-9DF8-0050568260A3
# 9998   BB720E30-7186-11e8-9A3E-0050569D7549
# 9999   358D43A1-B588-11e8-B9A6-0050569D3164
# 10000  FF93F9C4-9B8A-11e8-9A0E-0050569D5A2F
# 10001  FF93F9C4-9B8A-11e8-9A0E-0050569D5A2F
#
#                                      CampaignCodJ Medium_Type  Is_Email_Sent  \
# 0                         J-IF-SS UNITECH-APR-HYD       Email              1
# 1          J-HY-SS UNITECH-UNIDJNTIFIJD-FWC-19DJC       Email              1
# 2                      J-ST-SS UNITECH-SURJ-20MAR       Email              1
# 3            J-PO-SS UNITECH-UM-SALJNOTIDJNTIFIJD       Email              1
# ...

# %%
# Working with missing Data

data_missing = pd.read_csv("Email.csv", encoding="ISO-8859-1")
data_missing
# Out:
#                                  Unnamed: 0  \
# 0      04B738A5-71FD-11e8-A0F8-00505682069A
# 1      894FAAD2-6F3C-11e8-9252-0050568252F9
# 2      0918CDD9-5788-11e9-93F0-005056984FDD
# 3      0EC2729D-1618-11e8-B598-0050569D5A2F
# 4      CAAEDBE3-B411-11e8-ACF0-00505682069A
# ...                                     ...
# 9997   8980002F-7F6D-11e8-9DF8-0050568260A3
# 9998   BB720E30-7186-11e8-9A3E-0050569D7549
# 9999   358D43A1-B588-11e8-B9A6-0050569D3164
# 10000  FF93F9C4-9B8A-11e8-9A0E-0050569D5A2F
# 10001  FF93F9C4-9B8A-11e8-9A0E-0050569D5A2F
#
#                                      CampaignCodJ Medium_Type  Is_Email_Sent  \
# 0                         J-IF-SS UNITECH-APR-HYD       Email              1
# 1          J-HY-SS UNITECH-UNIDJNTIFIJD-FWC-19DJC       Email              1
# 2                      J-ST-SS UNITECH-SURJ-20MAR       Email              1
# 3            J-PO-SS UNITECH-UM-SALJNOTIDJNTIFIJD       Email              1
# ...

# %%
# finning the missing data
data_missing['Email_Click_Count'].fillna(data_missing['Email_Click_Count'].mean(), inplace=True)
data_missing
# Out:
#                                  Unnamed: 0  \
# 0      04B738A5-71FD-11e8-A0F8-00505682069A
# 1      894FAAD2-6F3C-11e8-9252-0050568252F9
# 2      0918CDD9-5788-11e9-93F0-005056984FDD
# 3      0EC2729D-1618-11e8-B598-0050569D5A2F
# 4      CAAEDBE3-B411-11e8-ACF0-00505682069A
# ...                                     ...
# 9997   8980002F-7F6D-11e8-9DF8-0050568260A3
# 9998   BB720E30-7186-11e8-9A3E-0050569D7549
# 9999   358D43A1-B588-11e8-B9A6-0050569D3164
# 10000  FF93F9C4-9B8A-11e8-9A0E-0050569D5A2F
# 10001  FF93F9C4-9B8A-11e8-9A0E-0050569D5A2F
#
#                                      CampaignCodJ Medium_Type  Is_Email_Sent  \
# 0                         J-IF-SS UNITECH-APR-HYD       Email              1
# 1          J-HY-SS UNITECH-UNIDJNTIFIJD-FWC-19DJC       Email              1
# 2                      J-ST-SS UNITECH-SURJ-20MAR       Email              1
# 3            J-PO-SS UNITECH-UM-SALJNOTIDJNTIFIJD       Email              1
# ...

# %%
# removing missing values/cleaning empty rows

data_missing.dropna(inplace=True)
data_missing
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, CampaignCodJ, Medium_Type, Is_Email_Sent, Email_Sent_Status, Email_SentDate, Email_Open_Count, Email_Click_Count, Is_SMS_Sent, SMS_SentDate]
# Index: []
